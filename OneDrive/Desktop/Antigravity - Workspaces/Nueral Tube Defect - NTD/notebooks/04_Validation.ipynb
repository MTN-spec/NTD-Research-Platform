# %% [markdown]
# # Chapter 5: Validation & Biomarker Identification
#
# ## 5.1 Introduction
# After training the models, it is crucial to understand *why* they make certain predictions. This notebook uses SHAP (SHapley Additive exPlanations) to identify the top genetic and transcriptomic features driving the risk of Neural Tube Defects.
#
# ## 5.2 SHAP Analysis

# %%
import shap
import pandas as pd
import matplotlib.pyplot as plt

# Initialize JS visualization for notebook
shap.initjs()

# We will explain the Random Forest model as it is often easier to interpret initially
# (Note: SHAP also works for XGBoost and Deep Learning)

# Create an explainer object
explainer = shap.TreeExplainer(rf_model)
shap_values = explainer.shap_values(X_test)

# Summary Plot: Shows the most important features
print("Top Features driving NTD Prediction:")
shap.summary_plot(shap_values[1], X_test, plot_type="bar")

# %% [markdown]
# ## 5.3 detailed Biomarker Analysis
# The dot plot below shows how the value of a feature impacts the model output.
# - **Red dots** = High value of that feature
# - **Blue dots** = Low value of that feature
# - **Right side** = Positive contribution to risk (Increases probability of NTD)
# - **Left side** = Negative contribution to risk (Decreases probability of NTD)
#
# For example, if "Gene_X_Expression" is Red and on the Left, it means high expression of Gene X is protective.

# %%
shap.summary_plot(shap_values[1], X_test)

# %% [markdown]
# ## 5.4 Conclusion
# By identifying these top features, we can cross-reference them with biological literature to confirm their role in folate metabolism or neural tube closure, fulfilling the biomarker discovery objective.
